# %% [markdown]
# # Installing packages in a VM cluster on Azure
# Expanding on the documentation here: https://cloudprovider.dask.org/en/latest/azure.html
#
# The problem is that you may need to install packages, and these packages may also need to be available on your cluster VMs.
# In this example, intake-esm is the package we want.

# %% [markdown]
# You can choose to use or not use a docker container, see below.

# %%
# Settings
env_name = "demo_env_name"

# %%
# Use this cell if the conda environment is not already set up
# You will then be able to select the env as a kernel in the jupyter notebook.
# This is controlled mainly by environment.yml,
# but env.sh installs the kernel for the jupyter notebook.
# You will probably not need to change env.sh.
# !. env.sh {env_name} environment.yml
# Out:
# conda is /anaconda/envs/azureml_py36/bin/conda
# demo_env_name            /anaconda/envs/demo_env_name
# activating environment demo_env_name
# Change kernel to demo_env_name, refresh browser if not available.

# %%
# You will need to set your own for these.
my_resource_group="PangeoHarvestOccupationalHeat"
my_vnet="PangeoHOH-vnet"
my_security_group="PangeoHOH-sg"
# See 

dockerhub_id = "charlessimpson" # You will need to set yours if using the docker method.

# %% [markdown]
# ## Not using a docker container

# %%
# You will need to login to Azure in order to launch the VMs.
# !az login

# %%
# If you decide not to docker, you can pass the dependencies to
# the AzureVMCluster constructor with the 'env_vars' keyword.
# You can generate the list of packages from your environment.yml,
# or list them manually.
# If you have a large number of dependencies this can be slow.
#
# If this doesn't work, check your dask version. 
# For dask versions before 23 Feb 2021 there is an issue,
# see https://github.com/dask/dask-cloudprovider/pull/258
#
# Parse the dependencies
import yaml
with open("environment.yml", 'r') as stream:
    try:
        env_yml = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)
env_yml

EXTRA_CONDA_PACKAGES=[]
EXTRA_PIP_PACKAGES=[]
for entry in env_yml["dependencies"]:
    if isinstance(entry, str):
        EXTRA_CONDA_PACKAGES.append(entry)
    elif isinstance(entry, dict):
        EXTRA_PIP_PACKAGES = entry['pip']
        
EXTRA_CONDA_PACKAGES = ' '.join(EXTRA_CONDA_PACKAGES)
EXTRA_PIP_PACKAGES = ' '.join(EXTRA_PIP_PACKAGES)

print("CONDA", EXTRA_CONDA_PACKAGES)
print("PIP", EXTRA_PIP_PACKAGES)
# Out:
# CONDA dask xarray pip
# PIP dask-cloudprovider[azure] intake-esm

# %%
# Setup the azure dask cluster
from dask_cloudprovider.azure import AzureVMCluster
from dask.distributed import Client


cluster = AzureVMCluster(resource_group=my_resource_group,
                         vnet=my_vnet,
                         security_group=my_security_group,
                         location="UK South",
                         env_vars={"EXTRA_PIP_PACKAGES": EXTRA_PIP_PACKAGES, "EXTRA_CONDA_PACKAGES": EXTRA_CONDA_PACKAGES},
                         n_workers=1
                        )

client = Client(cluster)
client
# Out:
# Creating scheduler instance
# Assigned public IP
# Network interface ready
# Creating VM
# Created VM dask-8b30dfd9-scheduler
# Waiting for scheduler to run at 40.120.40.69:8786
# Scheduler is running
# Creating worker instance
# /anaconda/envs/demo_env_name/lib/python3.9/contextlib.py:124: UserWarning: Creating your cluster is taking a surprisingly long time. This is likely due to pending resources. Hang tight!
#   next(self.gen)
# Network interface ready
# Creating VM
# Created VM dask-8b30dfd9-worker-5a3e7000
# /anaconda/envs/demo_env_name/lib/python3.9/site-packages/distributed/client.py:1148: VersionMismatchWarning: Mismatched versions found
#
# +---------+--------+-----------+---------+
# | Package | client | scheduler | workers |
# +---------+--------+-----------+---------+
# | blosc   | None   | 1.9.2     | None    |
# | lz4     | None   | 3.1.1     | None    |
# | msgpack | 1.0.2  | 1.0.0     | None    |
# +---------+--------+-----------+---------+
# Notes:
# -  msgpack: Variation is ok, as long as everything is above 0.6
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tls://10.0.0.18:8786' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Using a docker container
# This may be faster in the long run if you have a lot of dependencies.

# %%
# Build a docker container for running on the cluster VMs.
# This is controlled by the Dockerfile and the environment.yml
# You will probably not need to change the Dockerfile.
# !docker build -t {env_name} .
# Out:
# Sending build context to Docker daemon  120.3kB
# Step 1/8 : FROM continuumio/miniconda3:4.8.2
#  ---> b4adc22212f1
# Step 2/8 : RUN mkdir /opt/app
#  ---> Using cache
#  ---> b5a2c9c628ad
# Step 3/8 : COPY prepare.sh /usr/bin/prepare.sh
#  ---> Using cache
#  ---> d102a00b0315
# Step 4/8 : COPY environment.yml /opt/app/environment.yml
#  ---> eb1baf9ec09a
# Step 5/8 : RUN conda install mamba -n base -c conda-forge
#  ---> Running in 890331f030a5
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     certifi-2020.12.5          |   py37h89c1867_1         143 KB  conda-forge
#     conda-4.10.1               |   py37h89c1867_0         3.1 MB  conda-forge
#     icu-68.1                   |       h58526e2_0        13.0 MB  conda-forge
#     krb5-1.17.1                |       h173b8e3_0         1.3 MB
#     libarchive-3.5.1           |       hccf745f_2         1.5 MB  conda-forge
#     libcurl-7.76.1             |       hc4aaa36_1         328 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libgcc-ng-9.3.0            |      h2828fa1_19         7.8 MB  conda-forge
#     libgomp-9.3.0              |      h2828fa1_19         376 KB  conda-forge
#     libiconv-1.16              |       h516909a_0         1.4 MB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_0         808 KB  conda-forge
#     libsolv-0.7.18             |       h780b84a_0         439 KB  conda-forge
#     libssh2-1.9.0              |       ha56f1ee_6         226 KB  conda-forge
#     libstdcxx-ng-9.3.0         |      h6de172a_19         4.0 MB  conda-forge
#     libxml2-2.9.12             |       h72842e0_0         772 KB  conda-forge
#     lz4-c-1.9.3                |       h9c3ff4c_0         179 KB  conda-forge
#     lzo-2.10                   |    h516909a_1000         314 KB  conda-forge
#     mamba-0.13.0               |   py37h7f483ca_0         649 KB  conda-forge
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     reproc-14.2.1              |       h36c2ea0_0          28 KB  conda-forge
#     reproc-cpp-14.2.1          |       h58526e2_0          20 KB  conda-forge
#     xz-5.2.5                   |       h516909a_1         343 KB  conda-forge
#     zstd-1.5.0                 |       ha95c52a_0         490 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        40.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-1_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h7f98852_1
#   icu                conda-forge/linux-64::icu-68.1-h58526e2_0
#   krb5               pkgs/main/linux-64::krb5-1.17.1-h173b8e3_0
#   libarchive         conda-forge/linux-64::libarchive-3.5.1-hccf745f_2
#   libcurl            conda-forge/linux-64::libcurl-7.76.1-hc4aaa36_1
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1
#   libgomp            conda-forge/linux-64::libgomp-9.3.0-h2828fa1_19
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.43.0-h812cca2_0
#   libsolv            conda-forge/linux-64::libsolv-0.7.18-h780b84a_0
#   libssh2            conda-forge/linux-64::libssh2-1.9.0-ha56f1ee_6
#   libxml2            conda-forge/linux-64::libxml2-2.9.12-h72842e0_0
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.3-h9c3ff4c_0
#   lzo                conda-forge/linux-64::lzo-2.10-h516909a_1000
#   mamba              conda-forge/linux-64::mamba-0.13.0-py37h7f483ca_0
#   python_abi         conda-forge/linux-64::python_abi-3.7-1_cp37m
#   reproc             conda-forge/linux-64::reproc-14.2.1-h36c2ea0_0
#   reproc-cpp         conda-forge/linux-64::reproc-cpp-14.2.1-h58526e2_0
#   zstd               conda-forge/linux-64::zstd-1.5.0-ha95c52a_0
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.12.5-ha878542_0
#   certifi              pkgs/main::certifi-2019.11.28-py37_0 --> conda-forge::certifi-2020.12.5-py37h89c1867_1
#   conda                       pkgs/main::conda-4.8.2-py37_0 --> conda-forge::conda-4.10.1-py37h89c1867_0
#   libgcc-ng           pkgs/main::libgcc-ng-9.1.0-hdf63c60_0 --> conda-forge::libgcc-ng-9.3.0-h2828fa1_19
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.1.0-hdf63c6~ --> conda-forge::libstdcxx-ng-9.3.0-h6de172a_19
#   openssl              pkgs/main::openssl-1.1.1d-h7b6447c_4 --> conda-forge::openssl-1.1.1k-h7f98852_0
#   xz                         pkgs/main::xz-5.2.4-h14c3975_4 --> conda-forge::xz-5.2.5-h516909a_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# libssh2-1.9.0        | 226 KB    | ########## | 100%
# libxml2-2.9.12       | 772 KB    | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# xz-5.2.5             | 343 KB    | ########## | 100%
# reproc-cpp-14.2.1    | 20 KB     | ########## | 100%
# ca-certificates-2020 | 137 KB    | ########## | 100%
# libsolv-0.7.18       | 439 KB    | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
# openssl-1.1.1k       | 2.1 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
# zstd-1.5.0           | 490 KB    | ########## | 100%
# libgomp-9.3.0        | 376 KB    | ########## | 100%
# libcurl-7.76.1       | 328 KB    | ########## | 100%
# libarchive-3.5.1     | 1.5 MB    | ########## | 100%
# lz4-c-1.9.3          | 179 KB    | ########## | 100%
# conda-4.10.1         | 3.1 MB    | ########## | 100%
# certifi-2020.12.5    | 143 KB    | ########## | 100%
# python_abi-3.7       | 4 KB      | ########## | 100%
# reproc-14.2.1        | 28 KB     | ########## | 100%
# libnghttp2-1.43.0    | 808 KB    | ########## | 100%
# libiconv-1.16        | 1.4 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
# lzo-2.10             | 314 KB    | ########## | 100%
# mamba-0.13.0         | 649 KB    | ########## | 100%
# bzip2-1.0.8          | 484 KB    | ########## | 100%
# libev-4.33           | 104 KB    | ########## | 100%
# krb5-1.17.1          | 1.3 MB    | ########## | 100%
# icu-68.1             | 13.0 MB   | ########## | 100%
# c-ares-1.17.1        | 109 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# Removing intermediate container 890331f030a5
#  ---> 13543b97563c
# Step 6/8 : RUN /opt/conda/bin/mamba env update -n base -f /opt/app/environment.yml
#  ---> Running in ddbecead4bd1
# pkgs/main/noarch
# pkgs/r/noarch
# pkgs/r/linux-64
# pkgs/main/linux-64
# conda-forge/noarch
# conda-forge/linux-64
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - dask
#    - xarray
#
#
#   Package              Version  Build                Channel                    Size
# ──────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   bokeh                  2.3.2  py37h89c1867_0       conda-forge/linux-64       8 MB
#   click                  8.0.1  py37h89c1867_0       conda-forge/linux-64     145 KB
#   cloudpickle            1.6.0  py_0                 conda-forge/noarch        22 KB
#   cytoolz               0.11.0  py37h5e8e339_3       conda-forge/linux-64     403 KB
#   dask                2021.5.0  pyhd8ed1ab_0         conda-forge/noarch         4 KB
#   dask-core           2021.5.0  pyhd8ed1ab_0         conda-forge/noarch       735 KB
#   distributed         2021.5.0  py37h89c1867_0       conda-forge/linux-64       1 MB
#   freetype              2.10.4  h0708190_1           conda-forge/linux-64     890 KB
#   fsspec              2021.5.0  pyhd8ed1ab_0         conda-forge/noarch        77 KB
#   heapdict               1.0.1  py_0                 conda-forge/noarch         7 KB
#   importlib-metadata     4.0.1  py37h89c1867_0       conda-forge/linux-64      30 KB
#   jbig                     2.1  h7f98852_2003        conda-forge/linux-64      43 KB
#   jinja2                 3.0.1  pyhd8ed1ab_0         conda-forge/noarch        99 KB
#   jpeg                      9d  h516909a_0           conda-forge/linux-64     266 KB
#   lcms2                   2.12  hddcbb42_0           conda-forge/linux-64     443 KB
#   lerc                   2.2.1  h9c3ff4c_0           conda-forge/linux-64     213 KB
#   libblas                3.9.0  9_openblas           conda-forge/linux-64      11 KB
#   libcblas               3.9.0  9_openblas           conda-forge/linux-64      11 KB
#   libdeflate               1.7  h7f98852_5           conda-forge/linux-64      67 KB
#   libgfortran-ng         9.3.0  hff62375_19          conda-forge/linux-64      22 KB
#   libgfortran5           9.3.0  hff62375_19          conda-forge/linux-64       2 MB
#   liblapack              3.9.0  9_openblas           conda-forge/linux-64      11 KB
#   libopenblas           0.3.15  pthreads_h8fe5266_1  conda-forge/linux-64       9 MB
#   libpng                1.6.37  hed695b0_2           conda-forge/linux-64     359 KB
#   libtiff                4.3.0  hf544144_1           conda-forge/linux-64     668 KB
#   libwebp-base           1.2.0  h7f98852_2           conda-forge/linux-64     815 KB
#   locket                 0.2.1  py37h06a4308_1       pkgs/main/linux-64        10 KB
#   markupsafe             2.0.1  py37h5e8e339_0       conda-forge/linux-64      22 KB
#   msgpack-python         1.0.2  py37h2527ec5_1       conda-forge/linux-64      91 KB
#   numpy                 1.20.3  py37h038b26d_0       conda-forge/linux-64       6 MB
#   olefile                 0.46  pyh9f0ad1d_1         conda-forge/noarch        32 KB
#   packaging               20.9  pyh44b312d_0         conda-forge/noarch        35 KB
#   pandas                 1.2.4  py37h219a48f_0       conda-forge/linux-64      12 MB
#   partd                  1.2.0  pyhd8ed1ab_0         conda-forge/noarch        18 KB
#   pillow                 8.2.0  py37he98fc37_0       pkgs/main/linux-64       622 KB
#   psutil                 5.8.0  py37h5e8e339_1       conda-forge/linux-64     342 KB
#   pyparsing              2.4.7  pyh9f0ad1d_0         conda-forge/noarch        60 KB
#   python-dateutil        2.8.1  py_0                 conda-forge/noarch       220 KB
#   pytz                  2021.1  pyhd8ed1ab_0         conda-forge/noarch       239 KB
#   pyyaml                 5.3.1  py37h7b6447c_0       pkgs/main/linux-64       181 KB
#   sortedcontainers       2.4.0  pyhd8ed1ab_0         conda-forge/noarch        26 KB
#   tblib                  1.7.0  pyhd8ed1ab_0         conda-forge/noarch        15 KB
#   toolz                 0.11.1  py_0                 conda-forge/noarch        46 KB
#   tornado                  6.1  py37h5e8e339_1       conda-forge/linux-64     646 KB
#   typing_extensions    3.7.4.3  py_0                 conda-forge/noarch        25 KB
#   xarray                0.18.2  pyhd8ed1ab_0         conda-forge/noarch       599 KB
#   zict                   2.0.0  py_0                 conda-forge/noarch        10 KB
#   zipp                   3.4.1  pyhd8ed1ab_0         conda-forge/noarch        11 KB
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   pip                   20.0.2  py37_1               installed
#   pip                   21.1.2  pyhd8ed1ab_0         conda-forge/noarch         1 MB
#
#   Summary:
#
#   Install: 48 packages
#   Upgrade: 1 packages
#
#   Total download: 47 MB
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Looking for: ['dask', 'xarray', 'pip']
#
#
#
# Downloading and Extracting Packages
# tblib-1.7.0          | 15 KB     | ########## | 100%
# cloudpickle-1.6.0    | 22 KB     | ########## | 100%
# python-dateutil-2.8. | 220 KB    | ########## | 100%
# pyparsing-2.4.7      | 60 KB     | ########## | 100%
# jinja2-3.0.1         | 99 KB     | ########## | 100%
# bokeh-2.3.2          | 8.3 MB    | ########## | 100%
# zict-2.0.0           | 10 KB     | ########## | 100%
# libpng-1.6.37        | 359 KB    | ########## | 100%
# libdeflate-1.7       | 67 KB     | ########## | 100%
# libopenblas-0.3.15   | 9.2 MB    | ########## | 100%
# lerc-2.2.1           | 213 KB    | ########## | 100%
# markupsafe-2.0.1     | 22 KB     | ########## | 100%
# freetype-2.10.4      | 890 KB    | ########## | 100%
# lcms2-2.12           | 443 KB    | ########## | 100%
# distributed-2021.5.0 | 1.1 MB    | ########## | 100%
# dask-2021.5.0        | 4 KB      | ########## | 100%
# msgpack-python-1.0.2 | 91 KB     | ########## | 100%
# libcblas-3.9.0       | 11 KB     | ########## | 100%
# olefile-0.46         | 32 KB     | ########## | 100%
# packaging-20.9       | 35 KB     | ########## | 100%
# toolz-0.11.1         | 46 KB     | ########## | 100%
# fsspec-2021.5.0      | 77 KB     | ########## | 100%
# partd-1.2.0          | 18 KB     | ########## | 100%
# psutil-5.8.0         | 342 KB    | ########## | 100%
# jpeg-9d              | 266 KB    | ########## | 100%
# pytz-2021.1          | 239 KB    | ########## | 100%
# pyyaml-5.3.1         | 181 KB    | ########## | 100%
# locket-0.2.1         | 10 KB     | ########## | 100%
# libtiff-4.3.0        | 668 KB    | ########## | 100%
# libblas-3.9.0        | 11 KB     | ########## | 100%
# heapdict-1.0.1       | 7 KB      | ########## | 100%
# sortedcontainers-2.4 | 26 KB     | ########## | 100%
# libwebp-base-1.2.0   | 815 KB    | ########## | 100%
# pillow-8.2.0         | 622 KB    | ########## | 100%
# pandas-1.2.4         | 11.8 MB   | ########## | 100%
# cytoolz-0.11.0       | 403 KB    | ########## | 100%
# tornado-6.1          | 646 KB    | ########## | 100%
# xarray-0.18.2        | 599 KB    | ########## | 100%
# liblapack-3.9.0      | 11 KB     | ########## | 100%
# zipp-3.4.1           | 11 KB     | ########## | 100%
# importlib-metadata-4 | 30 KB     | ########## | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ########## | 100%
# click-8.0.1          | 145 KB    | ########## | 100%
# numpy-1.20.3         | 5.7 MB    | ########## | 100%
# jbig-2.1             | 43 KB     | ########## | 100%
# pip-21.1.2           | 1.1 MB    | ########## | 100%
# libgfortran5-9.3.0   | 2.0 MB    | ########## | 100%
# typing_extensions-3. | 25 KB     | ########## | 100%
# dask-core-2021.5.0   | 735 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['/opt/conda/bin/python', '-m', 'pip', 'install', '-U', '-r', '/opt/app/condaenv.rcvl4cbu.requirements.txt']
# Pip subprocess output:
# Collecting dask-cloudprovider[azure]
#   Downloading dask_cloudprovider-2021.3.1-py3-none-any.whl (61 kB)
# Collecting intake-esm
#   Downloading intake_esm-2021.1.15-py3-none-any.whl (26 kB)
# Requirement already satisfied: fsspec>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2021.5.0)
# Collecting intake>=0.6.0
#   Downloading intake-0.6.2-py3-none-any.whl (1.5 MB)
# Collecting requests>=2.24.0
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting zarr>=2.5
#   Downloading zarr-2.8.3-py3-none-any.whl (140 kB)
# Collecting netCDF4>=1.5.5
#   Downloading netCDF4-1.5.6-cp37-cp37m-manylinux2014_x86_64.whl (4.7 MB)
# Collecting fastprogress>=0.2.6
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Collecting h5netcdf>=0.8.1
#   Downloading h5netcdf-0.11.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: xarray>=0.16.2 in /opt/conda/lib/python3.7/site-packages (from intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (0.18.2)
# Requirement already satisfied: dask[complete] in /opt/conda/lib/python3.7/site-packages (from intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2021.5.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from fastprogress>=0.2.6->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (1.20.3)
# Collecting h5py
#   Downloading h5py-3.2.1-cp37-cp37m-manylinux1_x86_64.whl (4.1 MB)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting entrypoints
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from intake>=0.6.0->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from intake>=0.6.0->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (5.3.1)
# Collecting cftime
#   Downloading cftime-1.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (214 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.24.0->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.24.0->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.24.0->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.24.0->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2020.12.5)
# Requirement already satisfied: setuptools>=40.4 in /opt/conda/lib/python3.7/site-packages (from xarray>=0.16.2->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (45.2.0.post20200210)
# Requirement already satisfied: pandas>=1.0 in /opt/conda/lib/python3.7/site-packages (from xarray>=0.16.2->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1.0->xarray>=0.16.2->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1.0->xarray>=0.16.2->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->xarray>=0.16.2->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (1.14.0)
# Collecting asciitree
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
# Collecting fasteners
#   Downloading fasteners-0.16-py2.py3-none-any.whl (28 kB)
# Collecting numcodecs>=0.6.4
#   Downloading numcodecs-0.7.3-cp37-cp37m-manylinux2010_x86_64.whl (5.8 MB)
# Requirement already satisfied: toolz>=0.8.2 in /opt/conda/lib/python3.7/site-packages (from dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (0.11.1)
# Requirement already satisfied: partd>=0.3.10 in /opt/conda/lib/python3.7/site-packages (from dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: locket in /opt/conda/lib/python3.7/site-packages/locket-0.2.1-py3.7.egg (from partd>=0.3.10->dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: distributed>=2021.01.1 in /opt/conda/lib/python3.7/site-packages (from dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (2021.5.0)
# Collecting aiohttp>=3.7.3
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
# Requirement already satisfied: tornado>=5 in /opt/conda/lib/python3.7/site-packages (from dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (6.1)
# Collecting azure-mgmt-compute>=18.0.0
#   Downloading azure_mgmt_compute-20.0.0-py2.py3-none-any.whl (3.6 MB)
# Collecting azure-cli-core>=2.15.1
#   Downloading azure_cli_core-2.23.0-py3-none-any.whl (230 kB)
# Collecting azure-mgmt-network>=16.0.0
#   Downloading azure_mgmt_network-19.0.0-py2.py3-none-any.whl (20.9 MB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/conda/lib/python3.7/site-packages (from aiohttp>=3.7.3->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (3.7.4.3)
# Collecting attrs>=17.3.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting cryptography<3.4,>=3.2
#   Downloading cryptography-3.3.2-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting azure-cli-telemetry==1.0.6.*
#   Downloading azure_cli_telemetry-1.0.6-py3-none-any.whl (10 kB)
# Collecting msrest>=0.5.0
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting argcomplete~=1.8
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting msal<2.0.0,>=1.10.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting PyJWT==1.7.1
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pkginfo>=1.5.0.1
#   Downloading pkginfo-1.7.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pyopenssl>=17.1.0 in /opt/conda/lib/python3.7/site-packages (from azure-cli-core>=2.15.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (19.1.0)
# Requirement already satisfied: psutil~=5.8 in /opt/conda/lib/python3.7/site-packages (from azure-cli-core>=2.15.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (5.8.0)
# Collecting humanfriendly<10.0,>=4.7
#   Downloading humanfriendly-9.1-py2.py3-none-any.whl (86 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.7.2-py2.py3-none-any.whl (206 kB)
# Collecting msrestazure>=0.6.3
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Collecting adal~=1.2.7
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting knack~=0.8.1
#   Downloading knack-0.8.2-py3-none-any.whl (59 kB)
# Collecting applicationinsights<0.12,>=0.11.1
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting portalocker~=1.2
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: importlib-metadata<5,>=0.23 in /opt/conda/lib/python3.7/site-packages (from argcomplete~=1.8->azure-cli-core>=2.15.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (4.0.1)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.7/site-packages (from cryptography<3.4,>=3.2->azure-cli-core>=2.15.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.12->cryptography<3.4,>=3.2->azure-cli-core>=2.15.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (2.19)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /opt/conda/lib/python3.7/site-packages (from distributed>=2021.01.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: msgpack>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from distributed>=2021.01.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (1.0.2)
# Requirement already satisfied: click>=6.6 in /opt/conda/lib/python3.7/site-packages (from distributed>=2021.01.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (8.0.1)
# Requirement already satisfied: zict>=0.1.3 in /opt/conda/lib/python3.7/site-packages (from distributed>=2021.01.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from distributed>=2021.01.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<5,>=0.23->argcomplete~=1.8->azure-cli-core>=2.15.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (3.4.1)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pygments
#   Downloading Pygments-2.9.0-py3-none-any.whl (1.0 MB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
#   Downloading PyJWT-2.0.0-py3-none-any.whl (15 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: heapdict in /opt/conda/lib/python3.7/site-packages (from zict>=0.1.3->distributed>=2021.01.1->dask-cloudprovider[azure]->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: bokeh!=2.0.0,>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2.3.2)
# Requirement already satisfied: packaging>=16.8 in /opt/conda/lib/python3.7/site-packages (from bokeh!=2.0.0,>=1.0.0->dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (20.9)
# Requirement already satisfied: pillow>=7.1.0 in /opt/conda/lib/python3.7/site-packages (from bokeh!=2.0.0,>=1.0.0->dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (8.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from jinja2->intake>=0.6.0->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging>=16.8->bokeh!=2.0.0,>=1.0.0->dask[complete]->intake-esm->-r /opt/app/condaenv.rcvl4cbu.requirements.txt (line 2)) (2.4.7)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py): started
#   Building wheel for asciitree (setup.py): finished with status 'done'
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5035 sha256=fa9c857642717df3f2bc9f223a0fac0dd432b9a939f81dfd9de593cbd7b39f8c
#   Stored in directory: /root/.cache/pip/wheels/12/1c/38/0def51e15add93bff3f4bf9c248b94db0839b980b8535e72a0
# Successfully built asciitree
# Installing collected packages: requests, oauthlib, requests-oauthlib, PyJWT, multidict, isodate, cryptography, yarl, tabulate, pynacl, pygments, portalocker, msrest, jmespath, colorama, cached-property, bcrypt, azure-core, attrs, async-timeout, argcomplete, applicationinsights, adal, pkginfo, paramiko, numcodecs, msrestazure, msal, knack, humanfriendly, h5py, fasteners, entrypoints, cftime, azure-mgmt-core, azure-common, azure-cli-telemetry, asciitree, appdirs, aiohttp, zarr, netCDF4, intake, h5netcdf, fastprogress, dask-cloudprovider, azure-mgmt-network, azure-mgmt-compute, azure-cli-core, intake-esm
#   Attempting uninstall: requests
#     Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 2.8
#     Uninstalling cryptography-2.8:
#       Successfully uninstalled cryptography-2.8
# Successfully installed PyJWT-1.7.1 adal-1.2.7 aiohttp-3.7.4.post0 appdirs-1.4.4 applicationinsights-0.11.10 argcomplete-1.12.3 asciitree-0.3.3 async-timeout-3.0.1 attrs-21.2.0 azure-cli-core-2.23.0 azure-cli-telemetry-1.0.6 azure-common-1.1.27 azure-core-1.14.0 azure-mgmt-compute-20.0.0 azure-mgmt-core-1.2.2 azure-mgmt-network-19.0.0 bcrypt-3.2.0 cached-property-1.5.2 cftime-1.5.0 colorama-0.4.4 cryptography-3.3.2 dask-cloudprovider-2021.3.1 entrypoints-0.3 fasteners-0.16 fastprogress-1.0.0 h5netcdf-0.11.0 h5py-3.2.1 humanfriendly-9.1 intake-0.6.2 intake-esm-2021.1.15 isodate-0.6.0 jmespath-0.10.0 knack-0.8.2 msal-1.12.0 msrest-0.6.21 msrestazure-0.6.4 multidict-5.1.0 netCDF4-1.5.6 numcodecs-0.7.3 oauthlib-3.1.0 paramiko-2.7.2 pkginfo-1.7.0 portalocker-1.7.1 pygments-2.9.0 pynacl-1.4.0 requests-2.25.1 requests-oauthlib-1.3.0 tabulate-0.8.9 yarl-1.6.3 zarr-2.8.3
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate base
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Removing intermediate container ddbecead4bd1
#  ---> 3c10d8811f65
# Step 7/8 : RUN mamba install --yes     -c conda-forge     python==3.8     python-blosc     cytoolz     dask==2021.4.1     lz4     nomkl     numpy==1.18.1     pandas==1.0.1     tini==0.18.0     && mamba clean -tipsy     && find /opt/conda/ -type f,l -name '*.a' -delete     && find /opt/conda/ -type f,l -name '*.pyc' -delete     && find /opt/conda/ -type f,l -name '*.js.map' -delete     && find /opt/conda/lib/python*/site-packages/bokeh/server/static -type f,l -name '*.js' -not -name '*.min.js' -delete     && rm -rf /opt/conda/pkgs
#  ---> Running in 6f5b869a8f3d
# conda-forge/linux-64     Using cache
# conda-forge/noarch       Using cache
# pkgs/main/linux-64
# pkgs/main/noarch
# pkgs/r/linux-64
# pkgs/r/noarch
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - python==3.8
#    - python-blosc
#    - cytoolz
#    - dask==2021.4.1
#    - lz4
#    - nomkl
#    - numpy==1.18.1
#    - pandas==1.0.1
#    - tini==0.18.0
#
#
#   Package                   Version  Build                Channel                    Size
# ───────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────
#
#   blas                          1.1  openblas             conda-forge/linux-64       1 KB
#   blosc                      1.21.0  h9c3ff4c_0           conda-forge/linux-64     841 KB
#   brotlipy                    0.7.0  py38h497a2fe_1001    conda-forge/linux-64     341 KB
#   lz4                         3.1.3  py38hebdc3cf_0       conda-forge/linux-64      44 KB
#   nomkl                         3.0  0                    pkgs/main/linux-64        46 KB
#   openblas                   0.3.15  pthreads_h4748800_1  conda-forge/linux-64      10 MB
#   openjpeg                    2.4.0  hb52868f_1           conda-forge/linux-64     444 KB
#   python-blosc               1.10.2  py38h51da96c_0       conda-forge/linux-64     375 KB
#   tini                       0.18.0  h14c3975_1001        conda-forge/linux-64      12 KB
#
#   Change:
# ───────────────────────────────────────────────────────────────────────────────────────────
#
#   bokeh                       2.3.2  py37h89c1867_0       installed
#   bokeh                       2.3.2  py38h578d9bd_0       conda-forge/linux-64       8 MB
#   certifi                 2020.12.5  py37h89c1867_1       installed
#   certifi                 2020.12.5  py38h578d9bd_1       conda-forge/linux-64     143 KB
#   click                       8.0.1  py37h89c1867_0       installed
#   click                       8.0.1  py38h578d9bd_0       conda-forge/linux-64     146 KB
#   conda                      4.10.1  py37h89c1867_0       installed
#   conda                      4.10.1  py38h578d9bd_0       conda-forge/linux-64       3 MB
#   cytoolz                    0.11.0  py37h5e8e339_3       installed
#   cytoolz                    0.11.0  py38h497a2fe_3       conda-forge/linux-64     420 KB
#   distributed              2021.5.0  py37h89c1867_0       installed
#   distributed              2021.5.0  py38h06a4308_0       pkgs/main/linux-64         1 MB
#   importlib-metadata          4.0.1  py37h89c1867_0       installed
#   importlib-metadata          4.0.1  py38h578d9bd_0       conda-forge/linux-64      30 KB
#   locket                      0.2.1  py37h06a4308_1       installed
#   locket                      0.2.1  py38h06a4308_1       pkgs/main/linux-64        10 KB
#   mamba                      0.13.0  py37h7f483ca_0       installed
#   mamba                      0.13.0  py38h2aa5da1_0       conda-forge/linux-64     651 KB
#   markupsafe                  2.0.1  py37h5e8e339_0       installed
#   markupsafe                  2.0.1  py38h497a2fe_0       conda-forge/linux-64      22 KB
#   msgpack-python              1.0.2  py37h2527ec5_1       installed
#   msgpack-python              1.0.2  py38h1fd1430_1       conda-forge/linux-64      92 KB
#   pillow                      8.2.0  py37he98fc37_0       installed
#   pillow                      8.2.0  py38ha0e1e83_1       conda-forge/linux-64     688 KB
#   psutil                      5.8.0  py37h5e8e339_1       installed
#   psutil                      5.8.0  py38h497a2fe_1       conda-forge/linux-64     342 KB
#   pycosat                     0.6.3  py37h7b6447c_0       installed
#   pycosat                     0.6.3  py38h497a2fe_1006    conda-forge/linux-64     107 KB
#   pysocks                     1.7.1  py37_0               installed
#   pysocks                     1.7.1  py38h578d9bd_3       conda-forge/linux-64      27 KB
#   pyyaml                      5.3.1  py37h7b6447c_0       installed
#   pyyaml                      5.3.1  py38h7b6447c_0       pkgs/main/linux-64       185 KB
#   ruamel_yaml               0.15.87  py37h7b6447c_0       installed
#   ruamel_yaml               0.15.87  py38h7b6447c_0       pkgs/main/linux-64       259 KB
#   tornado                       6.1  py37h5e8e339_1       installed
#   tornado                       6.1  py38h497a2fe_1       conda-forge/linux-64     649 KB
#
#   Upgrade:
# ───────────────────────────────────────────────────────────────────────────────────────────
#
#   asn1crypto                  1.3.0  py37_0               installed
#   asn1crypto                  1.4.0  pyh9f0ad1d_0         conda-forge/noarch        78 KB
#   ca-certificates         2020.12.5  ha878542_0           installed
#   ca-certificates         2021.4.13  h06a4308_1           pkgs/main/linux-64       114 KB
#   cffi                       1.14.0  py37h2e261b9_0       installed
#   cffi                       1.14.4  py38ha312104_0       conda-forge/linux-64     226 KB
#   chardet                     3.0.4  py37_1003            installed
#   chardet                     4.0.0  py38h578d9bd_1       conda-forge/linux-64     199 KB
#   conda-package-handling      1.6.0  py37h7b6447c_0       installed
#   conda-package-handling      1.7.3  py38h497a2fe_0       conda-forge/linux-64     927 KB
#   cryptography                  2.8  py37h1ba5d50_0       installed
#   cryptography                3.4.7  py38ha5dfef3_0       conda-forge/linux-64       1 MB
#   idna                          2.8  py37_0               installed
#   idna                         2.10  pyh9f0ad1d_0         conda-forge/noarch        52 KB
#   pycparser                    2.19  py37_0               installed
#   pycparser                    2.20  pyh9f0ad1d_2         conda-forge/noarch        94 KB
#   pyopenssl                  19.1.0  py37_0               installed
#   pyopenssl                  20.0.1  pyhd8ed1ab_0         conda-forge/noarch        48 KB
#   python                      3.7.6  h0371630_2           installed
#   python                      3.8.0  h357f687_5           conda-forge/linux-64      38 MB
#   python_abi                    3.7  1_cp37m              installed
#   python_abi                    3.8  1_cp38               conda-forge/linux-64       4 KB
#   readline                      7.0  h7b6447c_5           installed
#   readline                      8.1  h46c0cb4_0           conda-forge/linux-64     295 KB
#   requests                   2.22.0  py37_1               installed
#   requests                   2.25.1  pyhd3deb0d_0         conda-forge/noarch        51 KB
#   setuptools                 45.2.0  py37_0               installed
#   setuptools                 52.0.0  py38h06a4308_0       pkgs/main/linux-64       714 KB
#   six                        1.14.0  py37_0               installed
#   six                        1.16.0  pyh6c4a22f_0         conda-forge/noarch        14 KB
#   tk                          8.6.8  hbc83047_0           installed
#   tk                         8.6.10  hed695b0_1           conda-forge/linux-64       3 MB
#   urllib3                    1.25.8  py37_0               installed
#   urllib3                    1.26.4  pyhd8ed1ab_0         conda-forge/noarch        99 KB
#   wheel                      0.34.2  py37_0               installed
#   wheel                      0.36.2  pyhd3deb0d_0         conda-forge/noarch        31 KB
#
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────────────────────────
#
#   dask                     2021.5.0  pyhd8ed1ab_0         installed
#   dask                     2021.4.1  pyhd8ed1ab_0         conda-forge/noarch         4 KB
#   dask-core                2021.5.0  pyhd8ed1ab_0         installed
#   dask-core                2021.4.1  pyhd8ed1ab_0         conda-forge/noarch       725 KB
#   numpy                      1.20.3  py37h038b26d_0       installed
#   numpy                      1.18.1  py38h8854b6b_1       conda-forge/linux-64       5 MB
#   pandas                      1.2.4  py37h219a48f_0       installed
#   pandas                      1.0.1  py38hb3f55d8_0       conda-forge/linux-64      11 MB
#
#   Summary:
#
#   Install: 9 packages
#   Change: 18 packages
#   Upgrade: 18 packages
#   Downgrade: 4 packages
#
#   Total download: 91 MB
#
# ───────────────────────────────────────────────────────────────────────────────────────────
#
# readline                  Finished readline                             (00m:00s)             295 KB      3 MB/s
# Finished readline                             (00m:00s)             295 KB      3 MB/s
# tini                      Finished tini                                 (00m:00s)              12 KB    106 KB/s
# Finished tini                                 (00m:00s)              12 KB    106 KB/s
# python_abi                Finished python_abi                           (00m:00s)               4 KB     26 KB/s
# Finished python_abi                           (00m:00s)               4 KB     26 KB/s
# blosc                     Finished blosc                                (00m:00s)             841 KB      7 MB/s
# Finished blosc                                (00m:00s)             841 KB      7 MB/s
# psutil                    Finished psutil                               (00m:00s)             342 KB      2 MB/s
# Finished psutil                               (00m:00s)             342 KB      2 MB/s
# msgpack-python            Finished msgpack-python                       (00m:00s)              92 KB    558 KB/s
# Finished msgpack-python                       (00m:00s)              92 KB    558 KB/s
# tk                        Finished tk                                   (00m:00s)               3 MB     22 MB/s
# Finished tk                                   (00m:00s)               3 MB     22 MB/s
# chardet                   Finished chardet                              (00m:01s)             199 KB      1 MB/s
# Finished chardet                              (00m:01s)             199 KB      1 MB/s
# lz4                       Finished lz4                                  (00m:01s)              44 KB    237 KB/s
# Finished lz4                                  (00m:01s)              44 KB    237 KB/s
# pycparser                 Finished pycparser                            (00m:01s)              94 KB    437 KB/s
# Finished pycparser                            (00m:01s)              94 KB    437 KB/s
# click                     Finished click                                (00m:01s)             146 KB    660 KB/s
# Finished click                                (00m:01s)             146 KB    660 KB/s
# brotlipy                  Finished brotlipy                             (00m:01s)             341 KB      1 MB/s
# Finished brotlipy                             (00m:01s)             341 KB      1 MB/s
# pyyaml                    Finished pyyaml                               (00m:01s)             185 KB    693 KB/s
# Finished pyyaml                               (00m:01s)             185 KB    693 KB/s
# pyopenssl                 Finished pyopenssl                            (00m:01s)              48 KB    169 KB/s
# Finished pyopenssl                            (00m:01s)              48 KB    169 KB/s
# setuptools                Finished setuptools                           (00m:01s)             714 KB      2 MB/s
# Finished setuptools                           (00m:01s)             714 KB      2 MB/s
# ca-certificates           Finished ca-certificates                      (00m:01s)             114 KB    326 KB/s
# Finished ca-certificates                      (00m:01s)             114 KB    326 KB/s
# dask                      Finished dask                                 (00m:01s)               4 KB     12 KB/s
# Finished dask                                 (00m:01s)               4 KB     12 KB/s
# distributed               Finished distributed                          (00m:01s)               1 MB      3 MB/s
# Finished distributed                          (00m:01s)               1 MB      3 MB/s
# ruamel_yaml               Finished ruamel_yaml                          (00m:01s)             259 KB    637 KB/s
# Finished ruamel_yaml                          (00m:01s)             259 KB    637 KB/s
# cffi                      Finished cffi                                 (00m:01s)             226 KB    522 KB/s
# Finished cffi                                 (00m:01s)             226 KB    522 KB/s
# certifi                   Finished certifi                              (00m:01s)             143 KB    315 KB/s
# Finished certifi                              (00m:01s)             143 KB    315 KB/s
# requests                  Finished requests                             (00m:01s)              51 KB    111 KB/s
# Finished requests                             (00m:01s)              51 KB    111 KB/s
# pillow                    Finished pillow                               (00m:01s)             688 KB      1 MB/s
# Finished pillow                               (00m:01s)             688 KB      1 MB/s
# blas                      Finished blas                                 (00m:01s)               1 KB      3 KB/s
# Finished blas                                 (00m:01s)               1 KB      3 KB/s
# openblas                  Finished openblas                             (00m:03s)              10 MB     25 MB/s
# Finished openblas                             (00m:03s)              10 MB     25 MB/s
# markupsafe                Finished markupsafe                           (00m:03s)              22 KB     46 KB/s
# Finished markupsafe                           (00m:03s)              22 KB     46 KB/s
# cytoolz                   Finished cytoolz                              (00m:03s)             420 KB    826 KB/s
# Finished cytoolz                              (00m:03s)             420 KB    826 KB/s
# dask-core                 Finished dask-core                            (00m:03s)             725 KB      1 MB/s
# Finished dask-core                            (00m:03s)             725 KB      1 MB/s
# pysocks                   Finished pysocks                              (00m:03s)              27 KB     53 KB/s
# Finished pysocks                              (00m:03s)              27 KB     53 KB/s
# idna                      Finished idna                                 (00m:03s)              52 KB    101 KB/s
# Finished idna                                 (00m:03s)              52 KB    101 KB/s
# urllib3                   Finished urllib3                              (00m:03s)              99 KB    180 KB/s
# Finished urllib3                              (00m:03s)              99 KB    180 KB/s
# wheel                     Finished wheel                                (00m:03s)              31 KB     55 KB/s
# Finished wheel                                (00m:03s)              31 KB     55 KB/s
# conda-package-handling    Finished conda-package-handling               (00m:03s)             927 KB      2 MB/s
# Finished conda-package-handling               (00m:03s)             927 KB      2 MB/s
# importlib-metadata        Finished importlib-metadata                   (00m:03s)              30 KB     51 KB/s
# Finished importlib-metadata                   (00m:03s)              30 KB     51 KB/s
# pycosat                   Finished pycosat                              (00m:03s)             107 KB    177 KB/s
# Finished pycosat                              (00m:03s)             107 KB    177 KB/s
# six                       Finished six                                  (00m:03s)              14 KB     22 KB/s
# Finished six                                  (00m:03s)              14 KB     22 KB/s
# ...
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.13.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['python==3.8', 'python-blosc', 'cytoolz', 'dask==2021.4.1', 'lz4', 'nomkl', 'numpy==1.18.1', 'pandas==1.0.1', 'tini==0.18.0']
#
#
# Downloading and Extracting Packages
# tqdm-4.42.1          | 56 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.13.0) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
# Cache location: /opt/conda/pkgs
# Will remove the following tarballs:
#
# /opt/conda/pkgs
# ---------------
# ca-certificates-2020.12.5-ha878542_0.tar.bz2     137 KB
# python_abi-3.7-1_cp37m.tar.bz2                 4 KB
# zstd-1.5.0-ha95c52a_0.tar.bz2                490 KB
# libgomp-9.3.0-h2828fa1_19.tar.bz2            376 KB
# libxml2-2.9.12-h72842e0_0.tar.bz2            772 KB
# krb5-1.17.1-h173b8e3_0.conda                 1.3 MB
# libnghttp2-1.43.0-h812cca2_0.tar.bz2         808 KB
# xz-5.2.5-h516909a_1.tar.bz2                  343 KB
# conda-4.10.1-py37h89c1867_0.tar.bz2          3.1 MB
# reproc-14.2.1-h36c2ea0_0.tar.bz2              28 KB
# _openmp_mutex-4.5-1_gnu.tar.bz2               22 KB
# _libgcc_mutex-0.1-conda_forge.tar.bz2          3 KB
# openssl-1.1.1k-h7f98852_0.tar.bz2            2.1 MB
# libssh2-1.9.0-ha56f1ee_6.tar.bz2             226 KB
# libsolv-0.7.18-h780b84a_0.tar.bz2            439 KB
# c-ares-1.17.1-h7f98852_1.tar.bz2             109 KB
# mamba-0.13.0-py37h7f483ca_0.tar.bz2          649 KB
# certifi-2020.12.5-py37h89c1867_1.tar.bz2     143 KB
# libarchive-3.5.1-hccf745f_2.tar.bz2          1.5 MB
# bzip2-1.0.8-h7f98852_4.tar.bz2               484 KB
# libev-4.33-h516909a_1.tar.bz2                104 KB
# libiconv-1.16-h516909a_0.tar.bz2             1.4 MB
# libstdcxx-ng-9.3.0-h6de172a_19.tar.bz2       4.0 MB
# libcurl-7.76.1-hc4aaa36_1.tar.bz2            328 KB
# lzo-2.10-h516909a_1000.tar.bz2               314 KB
# reproc-cpp-14.2.1-h58526e2_0.tar.bz2          20 KB
# icu-68.1-h58526e2_0.tar.bz2                 13.0 MB
# libgcc-ng-9.3.0-h2828fa1_19.tar.bz2          7.8 MB
# lz4-c-1.9.3-h9c3ff4c_0.tar.bz2               179 KB
# mamba-0.13.0-py38h2aa5da1_0.tar.bz2          651 KB
# click-8.0.1-py38h578d9bd_0.tar.bz2           146 KB
# tini-0.18.0-h14c3975_1001.tar.bz2             12 KB
# msgpack-python-1.0.2-py38h1fd1430_1.tar.bz2      92 KB
# locket-0.2.1-py38h06a4308_1.conda             10 KB
# brotlipy-0.7.0-py38h497a2fe_1001.tar.bz2     341 KB
# dask-2021.4.1-pyhd8ed1ab_0.tar.bz2             4 KB
# tqdm-4.42.1-py_0.conda                        56 KB
# cryptography-3.4.7-py38ha5dfef3_0.tar.bz2     1.1 MB
# importlib-metadata-4.0.1-py38h578d9bd_0.tar.bz2      30 KB
# certifi-2020.12.5-py38h578d9bd_1.tar.bz2     143 KB
# python-blosc-1.10.2-py38h51da96c_0.tar.bz2     375 KB
# pycosat-0.6.3-py38h497a2fe_1006.tar.bz2      107 KB
# requests-2.25.1-pyhd3deb0d_0.tar.bz2          51 KB
# bokeh-2.3.2-py38h578d9bd_0.tar.bz2           8.2 MB
# pillow-8.2.0-py38ha0e1e83_1.tar.bz2          688 KB
# markupsafe-2.0.1-py38h497a2fe_0.tar.bz2       22 KB
# nomkl-3.0-0.conda                             46 KB
# pycparser-2.20-pyh9f0ad1d_2.tar.bz2           94 KB
# dask-core-2021.4.1-pyhd8ed1ab_0.tar.bz2      725 KB
# urllib3-1.26.4-pyhd8ed1ab_0.tar.bz2           99 KB
# cffi-1.14.4-py38ha312104_0.tar.bz2           226 KB
# six-1.16.0-pyh6c4a22f_0.tar.bz2               14 KB
# setuptools-52.0.0-py38h06a4308_0.conda       714 KB
# pyyaml-5.3.1-py38h7b6447c_0.conda            185 KB
# wheel-0.36.2-pyhd3deb0d_0.tar.bz2             31 KB
# conda-4.10.1-py38h578d9bd_0.tar.bz2          3.1 MB
# pysocks-1.7.1-py38h578d9bd_3.tar.bz2          27 KB
# pyopenssl-20.0.1-pyhd8ed1ab_0.tar.bz2         48 KB
# cytoolz-0.11.0-py38h497a2fe_3.tar.bz2        420 KB
# openblas-0.3.15-pthreads_h4748800_1.tar.bz2     9.8 MB
# conda-package-handling-1.7.3-py38h497a2fe_0.tar.bz2     927 KB
# tk-8.6.10-hed695b0_1.tar.bz2                 3.2 MB
# chardet-4.0.0-py38h578d9bd_1.tar.bz2         199 KB
# readline-8.1-h46c0cb4_0.tar.bz2              295 KB
# python-3.8.0-h357f687_5.tar.bz2             38.4 MB
# tornado-6.1-py38h497a2fe_1.tar.bz2           649 KB
# numpy-1.18.1-py38h8854b6b_1.tar.bz2          5.3 MB
# ruamel_yaml-0.15.87-py38h7b6447c_0.conda     259 KB
# asn1crypto-1.4.0-pyh9f0ad1d_0.tar.bz2         78 KB
# distributed-2021.5.0-py38h06a4308_0.conda     1.1 MB
# openjpeg-2.4.0-hb52868f_1.tar.bz2            444 KB
# ca-certificates-2021.4.13-h06a4308_1.conda     114 KB
# blas-1.1-openblas.tar.bz2                      1 KB
# pandas-1.0.1-py38hb3f55d8_0.tar.bz2         11.4 MB
# blosc-1.21.0-h9c3ff4c_0.tar.bz2              841 KB
# psutil-5.8.0-py38h497a2fe_1.tar.bz2          342 KB
# lz4-3.1.3-py38hebdc3cf_0.tar.bz2              44 KB
# python_abi-3.8-1_cp38.tar.bz2                  4 KB
# idna-2.10-pyh9f0ad1d_0.tar.bz2                52 KB
# pandas-1.2.4-py37h219a48f_0.tar.bz2         11.8 MB
# psutil-5.8.0-py37h5e8e339_1.tar.bz2          342 KB
# pip-21.1.2-pyhd8ed1ab_0.tar.bz2              1.1 MB
# cytoolz-0.11.0-py37h5e8e339_3.tar.bz2        403 KB
# python-dateutil-2.8.1-py_0.tar.bz2           220 KB
# xarray-0.18.2-pyhd8ed1ab_0.tar.bz2           599 KB
# freetype-2.10.4-h0708190_1.tar.bz2           890 KB
# liblapack-3.9.0-9_openblas.tar.bz2            11 KB
# libgfortran-ng-9.3.0-hff62375_19.tar.bz2      22 KB
# heapdict-1.0.1-py_0.tar.bz2                    7 KB
# dask-2021.5.0-pyhd8ed1ab_0.tar.bz2             4 KB
# libdeflate-1.7-h7f98852_5.tar.bz2             67 KB
# libtiff-4.3.0-hf544144_1.tar.bz2             668 KB
# jbig-2.1-h7f98852_2003.tar.bz2                43 KB
# libpng-1.6.37-hed695b0_2.tar.bz2             359 KB
# markupsafe-2.0.1-py37h5e8e339_0.tar.bz2       22 KB
# msgpack-python-1.0.2-py37h2527ec5_1.tar.bz2      91 KB
# importlib-metadata-4.0.1-py37h89c1867_0.tar.bz2      30 KB
# jpeg-9d-h516909a_0.tar.bz2                   266 KB
# lerc-2.2.1-h9c3ff4c_0.tar.bz2                213 KB
# dask-core-2021.5.0-pyhd8ed1ab_0.tar.bz2      735 KB
# libwebp-base-1.2.0-h7f98852_2.tar.bz2        815 KB
# zict-2.0.0-py_0.tar.bz2                       10 KB
# typing_extensions-3.7.4.3-py_0.tar.bz2        25 KB
# pillow-8.2.0-py37he98fc37_0.conda            622 KB
# distributed-2021.5.0-py37h89c1867_0.tar.bz2     1.1 MB
# packaging-20.9-pyh44b312d_0.tar.bz2           35 KB
# libopenblas-0.3.15-pthreads_h8fe5266_1.tar.bz2     9.2 MB
# partd-1.2.0-pyhd8ed1ab_0.tar.bz2              18 KB
# locket-0.2.1-py37h06a4308_1.conda             10 KB
# libgfortran5-9.3.0-hff62375_19.tar.bz2       2.0 MB
# zipp-3.4.1-pyhd8ed1ab_0.tar.bz2               11 KB
# bokeh-2.3.2-py37h89c1867_0.tar.bz2           8.3 MB
# tblib-1.7.0-pyhd8ed1ab_0.tar.bz2              15 KB
# click-8.0.1-py37h89c1867_0.tar.bz2           145 KB
# jinja2-3.0.1-pyhd8ed1ab_0.tar.bz2             99 KB
# cloudpickle-1.6.0-py_0.tar.bz2                22 KB
# lcms2-2.12-hddcbb42_0.tar.bz2                443 KB
# pytz-2021.1-pyhd8ed1ab_0.tar.bz2             239 KB
# pyyaml-5.3.1-py37h7b6447c_0.conda            181 KB
# toolz-0.11.1-py_0.tar.bz2                     46 KB
# libcblas-3.9.0-9_openblas.tar.bz2             11 KB
# libblas-3.9.0-9_openblas.tar.bz2              11 KB
# olefile-0.46-pyh9f0ad1d_1.tar.bz2             32 KB
# tornado-6.1-py37h5e8e339_1.tar.bz2           646 KB
# sortedcontainers-2.4.0-pyhd8ed1ab_0.tar.bz2      26 KBWARNING: 'conda clean --source-cache' is deprecated.
#     Use 'conda build purge-all' to remove source cache files.
#
# pyparsing-2.4.7-pyh9f0ad1d_0.tar.bz2          60 KB
# fsspec-2021.5.0-pyhd8ed1ab_0.tar.bz2          77 KB
# numpy-1.20.3-py37h038b26d_0.tar.bz2          5.7 MB
#
# ---------------------------------------------------
# Total:                                     178.4 MB
#
# Removed ca-certificates-2020.12.5-ha878542_0.tar.bz2
# Removed python_abi-3.7-1_cp37m.tar.bz2
# Removed zstd-1.5.0-ha95c52a_0.tar.bz2
# Removed libgomp-9.3.0-h2828fa1_19.tar.bz2
# Removed libxml2-2.9.12-h72842e0_0.tar.bz2
# Removed krb5-1.17.1-h173b8e3_0.conda
# Removed libnghttp2-1.43.0-h812cca2_0.tar.bz2
# Removed xz-5.2.5-h516909a_1.tar.bz2
# Removed conda-4.10.1-py37h89c1867_0.tar.bz2
# Removed reproc-14.2.1-h36c2ea0_0.tar.bz2
# Removed _openmp_mutex-4.5-1_gnu.tar.bz2
# Removed _libgcc_mutex-0.1-conda_forge.tar.bz2
# Removed openssl-1.1.1k-h7f98852_0.tar.bz2
# Removed libssh2-1.9.0-ha56f1ee_6.tar.bz2
# Removed libsolv-0.7.18-h780b84a_0.tar.bz2
# Removed c-ares-1.17.1-h7f98852_1.tar.bz2
# Removed mamba-0.13.0-py37h7f483ca_0.tar.bz2
# Removed certifi-2020.12.5-py37h89c1867_1.tar.bz2
# Removed libarchive-3.5.1-hccf745f_2.tar.bz2
# Removed bzip2-1.0.8-h7f98852_4.tar.bz2
# Removed libev-4.33-h516909a_1.tar.bz2
# Removed libiconv-1.16-h516909a_0.tar.bz2
# Removed libstdcxx-ng-9.3.0-h6de172a_19.tar.bz2
# Removed libcurl-7.76.1-hc4aaa36_1.tar.bz2
# Removed lzo-2.10-h516909a_1000.tar.bz2
# Removed reproc-cpp-14.2.1-h58526e2_0.tar.bz2
# Removed icu-68.1-h58526e2_0.tar.bz2
# Removed libgcc-ng-9.3.0-h2828fa1_19.tar.bz2
# Removed lz4-c-1.9.3-h9c3ff4c_0.tar.bz2
# Removed mamba-0.13.0-py38h2aa5da1_0.tar.bz2
# Removed click-8.0.1-py38h578d9bd_0.tar.bz2
# Removed tini-0.18.0-h14c3975_1001.tar.bz2
# Removed msgpack-python-1.0.2-py38h1fd1430_1.tar.bz2
# Removed locket-0.2.1-py38h06a4308_1.conda
# Removed brotlipy-0.7.0-py38h497a2fe_1001.tar.bz2
# Removed dask-2021.4.1-pyhd8ed1ab_0.tar.bz2
# Removed tqdm-4.42.1-py_0.conda
# Removed cryptography-3.4.7-py38ha5dfef3_0.tar.bz2
# Removed importlib-metadata-4.0.1-py38h578d9bd_0.tar.bz2
# Removed certifi-2020.12.5-py38h578d9bd_1.tar.bz2
# Removed python-blosc-1.10.2-py38h51da96c_0.tar.bz2
# Removed pycosat-0.6.3-py38h497a2fe_1006.tar.bz2
# Removed requests-2.25.1-pyhd3deb0d_0.tar.bz2
# Removed bokeh-2.3.2-py38h578d9bd_0.tar.bz2
# Removed pillow-8.2.0-py38ha0e1e83_1.tar.bz2
# Removed markupsafe-2.0.1-py38h497a2fe_0.tar.bz2
# Removed nomkl-3.0-0.conda
# Removed pycparser-2.20-pyh9f0ad1d_2.tar.bz2
# Removed dask-core-2021.4.1-pyhd8ed1ab_0.tar.bz2
# Removed urllib3-1.26.4-pyhd8ed1ab_0.tar.bz2
# Removed cffi-1.14.4-py38ha312104_0.tar.bz2
# Removed six-1.16.0-pyh6c4a22f_0.tar.bz2
# Removed setuptools-52.0.0-py38h06a4308_0.conda
# Removed pyyaml-5.3.1-py38h7b6447c_0.conda
# Removed wheel-0.36.2-pyhd3deb0d_0.tar.bz2
# Removed conda-4.10.1-py38h578d9bd_0.tar.bz2
# Removed pysocks-1.7.1-py38h578d9bd_3.tar.bz2
# Removed pyopenssl-20.0.1-pyhd8ed1ab_0.tar.bz2
# Removed cytoolz-0.11.0-py38h497a2fe_3.tar.bz2
# Removed openblas-0.3.15-pthreads_h4748800_1.tar.bz2
# Removed conda-package-handling-1.7.3-py38h497a2fe_0.tar.bz2
# Removed tk-8.6.10-hed695b0_1.tar.bz2
# Removed chardet-4.0.0-py38h578d9bd_1.tar.bz2
# Removed readline-8.1-h46c0cb4_0.tar.bz2
# Removed python-3.8.0-h357f687_5.tar.bz2
# Removed tornado-6.1-py38h497a2fe_1.tar.bz2
# Removed numpy-1.18.1-py38h8854b6b_1.tar.bz2
# Removed ruamel_yaml-0.15.87-py38h7b6447c_0.conda
# Removed asn1crypto-1.4.0-pyh9f0ad1d_0.tar.bz2
# Removed distributed-2021.5.0-py38h06a4308_0.conda
# Removed openjpeg-2.4.0-hb52868f_1.tar.bz2
# Removed ca-certificates-2021.4.13-h06a4308_1.conda
# Removed blas-1.1-openblas.tar.bz2
# Removed pandas-1.0.1-py38hb3f55d8_0.tar.bz2
# Removed blosc-1.21.0-h9c3ff4c_0.tar.bz2
# Removed psutil-5.8.0-py38h497a2fe_1.tar.bz2
# Removed lz4-3.1.3-py38hebdc3cf_0.tar.bz2
# Removed python_abi-3.8-1_cp38.tar.bz2
# Removed idna-2.10-pyh9f0ad1d_0.tar.bz2
# Removed pandas-1.2.4-py37h219a48f_0.tar.bz2
# Removed psutil-5.8.0-py37h5e8e339_1.tar.bz2
# Removed pip-21.1.2-pyhd8ed1ab_0.tar.bz2
# Removed cytoolz-0.11.0-py37h5e8e339_3.tar.bz2
# Removed python-dateutil-2.8.1-py_0.tar.bz2
# Removed xarray-0.18.2-pyhd8ed1ab_0.tar.bz2
# Removed freetype-2.10.4-h0708190_1.tar.bz2
# Removed liblapack-3.9.0-9_openblas.tar.bz2
# Removed libgfortran-ng-9.3.0-hff62375_19.tar.bz2
# Removed heapdict-1.0.1-py_0.tar.bz2
# Removed dask-2021.5.0-pyhd8ed1ab_0.tar.bz2
# Removed libdeflate-1.7-h7f98852_5.tar.bz2
# Removed libtiff-4.3.0-hf544144_1.tar.bz2
# Removed jbig-2.1-h7f98852_2003.tar.bz2
# Removed libpng-1.6.37-hed695b0_2.tar.bz2
# Removed markupsafe-2.0.1-py37h5e8e339_0.tar.bz2
# Removed msgpack-python-1.0.2-py37h2527ec5_1.tar.bz2
# Removed importlib-metadata-4.0.1-py37h89c1867_0.tar.bz2
# Removed jpeg-9d-h516909a_0.tar.bz2
# Removed lerc-2.2.1-h9c3ff4c_0.tar.bz2
# Removed dask-core-2021.5.0-pyhd8ed1ab_0.tar.bz2
# Removed libwebp-base-1.2.0-h7f98852_2.tar.bz2
# Removed zict-2.0.0-py_0.tar.bz2
# Removed typing_extensions-3.7.4.3-py_0.tar.bz2
# Removed pillow-8.2.0-py37he98fc37_0.conda
# Removed distributed-2021.5.0-py37h89c1867_0.tar.bz2
# Removed packaging-20.9-pyh44b312d_0.tar.bz2
# Removed libopenblas-0.3.15-pthreads_h8fe5266_1.tar.bz2
# Removed partd-1.2.0-pyhd8ed1ab_0.tar.bz2
# Removed locket-0.2.1-py37h06a4308_1.conda
# Removed libgfortran5-9.3.0-hff62375_19.tar.bz2
# Removed zipp-3.4.1-pyhd8ed1ab_0.tar.bz2
# Removed bokeh-2.3.2-py37h89c1867_0.tar.bz2
# Removed tblib-1.7.0-pyhd8ed1ab_0.tar.bz2
# Removed click-8.0.1-py37h89c1867_0.tar.bz2
# Removed jinja2-3.0.1-pyhd8ed1ab_0.tar.bz2
# Removed cloudpickle-1.6.0-py_0.tar.bz2
# Removed lcms2-2.12-hddcbb42_0.tar.bz2
# Removed pytz-2021.1-pyhd8ed1ab_0.tar.bz2
# Removed pyyaml-5.3.1-py37h7b6447c_0.conda
# Removed toolz-0.11.1-py_0.tar.bz2
# Removed libcblas-3.9.0-9_openblas.tar.bz2
# Removed libblas-3.9.0-9_openblas.tar.bz2
# Removed olefile-0.46-pyh9f0ad1d_1.tar.bz2
# Removed tornado-6.1-py37h5e8e339_1.tar.bz2
# Removed sortedcontainers-2.4.0-pyhd8ed1ab_0.tar.bz2
# Removed pyparsing-2.4.7-pyh9f0ad1d_0.tar.bz2
# Removed fsspec-2021.5.0-pyhd8ed1ab_0.tar.bz2
# Removed numpy-1.20.3-py37h038b26d_0.tar.bz2
# WARNING: /root/.conda/pkgs does not exist
# Cache location: /opt/conda/pkgs
# Will remove the following packages:
# /opt/conda/pkgs
# ---------------
#
# _openmp_mutex-4.5-1_gnu                       93 KB
# _libgcc_mutex-0.1-conda_forge                  6 KB
# python_abi-3.7-1_cp37m                        10 KB
# blas-1.1-openblas                              3 KB
# nomkl-3.0-0                                  281 KB
# python_abi-3.8-1_cp38                         10 KB
# dask-2021.4.1-pyhd8ed1ab_0                    11 KB
# libcblas-3.9.0-9_openblas                     41 KB
# libgfortran-ng-9.3.0-hff62375_19              92 KB
# libblas-3.9.0-9_openblas                      42 KB
# liblapack-3.9.0-9_openblas                    41 KB
# dask-2021.5.0-pyhd8ed1ab_0                    11 KB
#
# ---------------------------------------------------
# Total:                                       642 KB
#
# removing _openmp_mutex-4.5-1_gnu
# removing _libgcc_mutex-0.1-conda_forge
# removing python_abi-3.7-1_cp37m
# removing blas-1.1-openblas
# removing nomkl-3.0-0
# removing python_abi-3.8-1_cp38
# removing dask-2021.4.1-pyhd8ed1ab_0
# removing libcblas-3.9.0-9_openblas
# removing libgfortran-ng-9.3.0-hff62375_19
# removing libblas-3.9.0-9_openblas
# removing liblapack-3.9.0-9_openblas
# removing dask-2021.5.0-pyhd8ed1ab_0
# Removing intermediate container 6f5b869a8f3d
#  ---> d572aa1a3a50
# Step 8/8 : ENTRYPOINT ["tini", "-g", "--", "/usr/bin/prepare.sh"]
#  ---> Running in c8669678bdd4
# Removing intermediate container c8669678bdd4
#  ---> 2579cd8dbf9e
# Successfully built 2579cd8dbf9e
# Successfully tagged demo_env_name:latest

# %%
# You will need to login to dockerhub - you will need to open a terminal to do this
# Or use the --username and --password flags.
# Obviously I won't put my credentials here.
# !docker login

# %%
# This identifies the local docker container you just made
# with a remote repository in your dockerhub account.
# !docker tag {env_name}:latest {dockerhub_id}/{env_name}:latest

# %%
# This pushes the docker image to your dockerhub account.
# This is necessary because when you launch the dask VMs, 
# they will not have access to the local files of the machine
# you are running this notebook on, and instead will retrieve 
# the container from dockerhub.
# !docker push {dockerhub_id}/{env_name}:latest
# Out:
# The push refers to repository [docker.io/charlessimpson/demo_env_name]
#
# fae8c2c9: Preparing
# 91c16778: Preparing
# b08efadf: Preparing
# e9e21ff8: Preparing
# 12c0e863: Preparing
# a11e566d: Preparing
# d39597dd: Preparing
# 20aa853c: Preparing
# 91c16778: Pushed   1.028GB/1.001GBAPushing  630.8MB/1.001GBlatest: digest: sha256:2596d181b30c35859ab3318240924baba2caa231c104bf57b34be35a363bb51a size: 2212

# %%
# You will need to login to Azure in order to launch the VMs.
# !az login

# %%
# Setup the azure dask cluster
from dask_cloudprovider.azure import AzureVMCluster
from dask.distributed import Client


cluster = AzureVMCluster(resource_group=my_resource_group,
                         vnet=my_vnet,
                         security_group=my_security_group,
                         location="UK South",
                         docker_image=f'{dockerhub_id}/{env_name}:latest',
                         n_workers=1
                        )

client = Client(cluster)
client
# Out:
# Creating scheduler instance
# Assigned public IP
# Network interface ready
# Creating VM
# Created VM dask-d4e576d8-scheduler
# Waiting for scheduler to run at 40.120.40.80:8786
# Scheduler is running
# Creating worker instance
# Network interface ready
# Creating VM
# Created VM dask-d4e576d8-worker-aaa9a7a4
# /anaconda/envs/demo_env_name/lib/python3.9/site-packages/distributed/client.py:1148: VersionMismatchWarning: Mismatched versions found
#
# +---------+-----------+-----------+---------+
# | Package | client    | scheduler | workers |
# +---------+-----------+-----------+---------+
# | blosc   | None      | 1.10.2    | None    |
# | dask    | 2021.05.0 | 2021.04.1 | None    |
# | lz4     | None      | 3.1.3     | None    |
# +---------+-----------+-----------+---------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tls://10.0.0.20:8786' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Prove it worked

# %%
client.run("import intake_esm; print(intake_esm.__version__)")
# Out:
# {}
